# %% [markdown]
# # Setup

# %% [markdown]
# ### Imports + Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Loading data

# %%
categories = pd.read_csv('data/allCategories.csv')
numbers = pd.read_csv('data/allNumbers.csv')
shades = pd.read_csv('data/allShades.csv')

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5307 entries, 0 to 5306
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   brand       5307 non-null   object
#  1   product     5307 non-null   object
#  2   url         5307 non-null   object
#  3   imgSrc      5307 non-null   object
#  4   name        5307 non-null   object
#  5   categories  5307 non-null   object
#  6   specific    3398 non-null   object
#  7   hex         5307 non-null   object
#  8   lightness   5307 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 373.3+ KB

# %%
numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3117 entries, 0 to 3116
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        3117 non-null   object
#  1   product      3117 non-null   object
#  2   name         2016 non-null   object
#  3   specific     3117 non-null   object
#  4   lightness    3117 non-null   float64
#  5   hex          3117 non-null   object
#  6   lightToDark  2991 non-null   object
#  7   numbers      3117 non-null   float64
#  8   id           2991 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 219.3+ KB

# %%
shades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6816 entries, 0 to 6815
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        6816 non-null   object
#  1   product      6816 non-null   object
#  2   url          6816 non-null   object
#  3   description  6816 non-null   object
#  4   imgSrc       6816 non-null   object
#  5   imgAlt       6816 non-null   object
#  6   name         4955 non-null   object
#  7   specific     4905 non-null   object
#  8   colorspace   6816 non-null   object
#  9   hex          6816 non-null   object
#  10  hue          6816 non-null   float64
#  11  sat          6816 non-null   float64
#  12  lightness    6816 non-null   float64
# dtypes: float64(3), object(10)
# memory usage: 692.4+ KB

# %%
categories
# Out:
#                       brand  \
# 0           BECCA Cosmetics
# 1           BECCA Cosmetics
# 2           BECCA Cosmetics
# 3           BECCA Cosmetics
# 4           BECCA Cosmetics
# ...                     ...
# 5302                Lancôme
# 5303                Antonym
# 5304      Benefit Cosmetics
# 5305  Urban Decay Cosmetics
# 5306           bareMinerals
#
#                                                 product  \
# 0                  Ultimate Coverage 24 Hour Foundation
# 1                  Ultimate Coverage 24 Hour Foundation
# 2                  Ultimate Coverage 24 Hour Foundation
# 3                  Ultimate Coverage 24 Hour Foundation
# 4                  Ultimate Coverage 24 Hour Foundation
# ...                                                 ...
# 5302  Bienfait Teinté Beauty Balm Sunscreen Broad Sp...
# 5303                 Certified Organic Baked Foundation
# 5304                   Hello Happy Soft Blur Foundation
# ...

# %%
shades
# Out:
#                         brand  \
# 0     Anastasia Beverly Hills
# 1     Anastasia Beverly Hills
# 2     Anastasia Beverly Hills
# 3     Anastasia Beverly Hills
# 4     Anastasia Beverly Hills
# ...                       ...
# 6811                  Lancôme
# 6812                  Antonym
# 6813        Benefit Cosmetics
# 6814    Urban Decay Cosmetics
# 6815             bareMinerals
#
#                                                 product  \
# 0                                   Luminous Foundation
# 1                                   Luminous Foundation
# 2                                   Luminous Foundation
# 3                                   Luminous Foundation
# 4                                   Luminous Foundation
# ...                                                 ...
# 6811  Bienfait Teinté Beauty Balm Sunscreen Broad Sp...
# 6812                 Certified Organic Baked Foundation
# 6813                   Hello Happy Soft Blur Foundation
# ...

# %%
numbers
# Out:
#                   brand                                            product  \
# 0     Makeup Revolution          Conceal & Define Full Coverage Foundation
# 1             HOURGLASS                                  Veil Fluid Makeup
# 2              TOM FORD                    Traceless Soft Matte Foundation
# 3         Armani Beauty                                Neo Nude Foundation
# 4              TOM FORD                         Traceless Foundation Stick
# ...                 ...                                                ...
# 3112      Juvia's Place                              I Am Magic Foundation
# 3113            Origins  Pretty in Bloom™ SPF 20 Flower-Infused Long-We...
# 3114      Juvia's Place                              I Am Magic Foundation
# 3115            Origins  Pretty in Bloom™ SPF 20 Flower-Infused Long-We...
# 3116              Almay          Clear Complexion Make Myself Clear Makeup
#
# ...

# %%
shades.describe()
# Out:
#                hue          sat    lightness
# count  6816.000000  6816.000000  6816.000000
# mean     24.863998     0.517515     0.633914
# std       6.046594     0.161520     0.162984
# min       0.000000     0.000000     0.154902
# 25%      21.818182     0.405405     0.517647
# 50%      25.333333     0.500000     0.662745
# 75%      28.387097     0.613361     0.758824
# max     230.400000     1.000000     0.996078

# %%
shades.columns
# Out:
# Index(['brand', 'product', 'url', 'description', 'imgSrc', 'imgAlt', 'name',
#        'specific', 'colorspace', 'hex', 'hue', 'sat', 'lightness'],
#       dtype='object')

# %%
shades['brand'].value_counts()
# Out:
# brand
# bareMinerals                 370
# Tarte                        242
# Clinique                     232
# SEPHORA COLLECTION           229
# MAC                          185
#                             ...
# COOLA                          3
# Marc Jacobs Beauty             3
# Dr. Dennis Gross Skincare      2
# KIKO Milano                    2
# Black Up                       1
# Name: count, Length: 107, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
shades[shades['brand']=='bareMinerals']
# Out:
#              brand                                            product  \
# 809   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 810   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 811   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 812   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 813   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 814   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 815   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 816   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 817   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 818   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 819   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# 820   bareMinerals             Matte Foundation Broad Spectrum SPF 15
# ...

# %%
shades[shades['brand']=='bareMinerals'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 809 to 6815
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        370 non-null    object
#  1   product      370 non-null    object
#  2   url          370 non-null    object
#  3   description  370 non-null    object
#  4   imgSrc       370 non-null    object
#  5   imgAlt       370 non-null    object
#  6   name         370 non-null    object
#  7   specific     368 non-null    object
#  8   colorspace   370 non-null    object
#  9   hex          370 non-null    object
#  10  hue          370 non-null    float64
#  11  sat          370 non-null    float64
#  12  lightness    370 non-null    float64
# dtypes: float64(3), object(10)
# memory usage: 40.5+ KB

# %%
shades['brand'].nunique()
# Out:
# 107

# %%
brands = shades['brand'].unique()
for value in brands:
    print(value)
# Out:
# Anastasia Beverly Hills
# BECCA Cosmetics
# Benefit Cosmetics
# It Cosmetics
# KVD Vegan Beauty
# Lancôme
# Laura Mercier
# NARS
# NUDESTIX
# Perricone MD
# Smashbox
# Tarte
# Too Faced
# Urban Decay Cosmetics
# CoverGirl
# ULTA
# J.Cat Beauty
# Catrice
# BLK/OPL
# Maybelline
# bareMinerals
# Makeup Revolution
# COVER FX
# HOURGLASS
# NYX Professional Makeup
# W3LL PEOPLE
# PÜR
# Winky Lux
# Milani
# Burt's Bees
# L'Oréal
# MAC
# Au Naturale
# Clinique
# jane iredale
# Estée Lauder
# Dermablend
# Wet n Wild
# Hynt Beauty
# e.l.f. Cosmetics
# KIKO Milano
# Pacifica
# Beauty Bakerie
# L.A. Girl
# Revlon
# Almay
# Juice Beauty
# Physicians Formula
# Morphe
# UOMA Beauty
# Elcie Cosmetics
# Juvia's Place
# Ofra Cosmetics
# florence by mills
# LORAC
# The Ordinary
# ColourPop
# FLOWER Beauty
# VDL
# ZOEVA
# Essence
# Exa
# SMITH & CULT
# Dose Of Colors
# FENTY BEAUTY by Rihanna
# Armani Beauty
# ILIA
# MAKE UP FOR EVER
# beautyblender
# Rare Beauty by Selena Gomez
# Charlotte Tilbury
# ...

# %%
shades.describe()
# Out:
#                hue          sat    lightness
# count  6816.000000  6816.000000  6816.000000
# mean     24.863998     0.517515     0.633914
# std       6.046594     0.161520     0.162984
# min       0.000000     0.000000     0.154902
# 25%      21.818182     0.405405     0.517647
# 50%      25.333333     0.500000     0.662745
# 75%      28.387097     0.613361     0.758824
# max     230.400000     1.000000     0.996078
